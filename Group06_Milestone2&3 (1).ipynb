# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Loading Datasets

# %%
#loading the datasets

flight = pd.read_csv("/content/drive/MyDrive/Data-Mining/flights.csv")
flight.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T05:00:00Z
# 1      1416     5      29  2013-01-01T05:00:00Z
# 2      1089     5      40  2013-01-01T05:00:00Z
# 3      1576     5      45  2013-01-01T05:00:00Z
# 4       762     6       0  2013-01-01T06:00:00Z

# %%
plane_data = pd.read_csv("/content/drive/MyDrive/Data-Mining/plane-data.csv")
plane_data.head()
# Out:
#   tailnum type manufacturer issue_date model status aircraft_type engine_type  \
# 0  N050AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 1  N051AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 2  N052AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 3  N054AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 4  N055AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
#
#    year
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
flight_routes = pd.read_csv("/content/drive/MyDrive/Data-Mining/us_flight_routes.csv", encoding ="utf-16",delimiter='\t')
flight_routes.tail()
# Out:
#       Airport ID Destination Airport Destination City Destination Country  \
# 4959        3469                 ATL          Atlanta       United States
# 4960        3682                 MIA            Miami       United States
# 4961        3576                 ATL          Atlanta       United States
# 4962        3682                 ORD          Chicago       United States
# 4963        3830                 ATL          Atlanta       United States
#
#                                       Destination Name  Distance  \
# 4959  Hartsfield Jackson Atlanta International Airport     False
# 4960                       Miami International Airport      True
# 4961  Hartsfield Jackson Atlanta International Airport      True
# 4962              Chicago O'Hare International Airport      True
# 4963  Hartsfield Jackson Atlanta International Airport      True
#
#      Origin Airport    Origin City Origin Country  \
# 4959            SFO  San Francisco  United States
# 4960            ATL        Atlanta  United States
# 4961            MIA          Miami  United States
# 4962            ATL        Atlanta  United States
# 4963            ORD        Chicago  United States
#
#                                            Origin Name   Buffer  \
# 4959               San Francisco International Airport  Polygon
# 4960  Hartsfield Jackson Atlanta International Airport  Polygon
# 4961                       Miami International Airport  Polygon
# 4962  Hartsfield Jackson Atlanta International Airport  Polygon
# 4963              Chicago O'Hare International Airport  Polygon
#
#       Destination Airport ID  Destination Latitude  Destination Longitude  \
# 4959                    3682               33.6367             -84.428101
# 4960                    3576               25.7932             -80.290604
# 4961                    3682               33.6367             -84.428101
# 4962                    3830               41.9786             -87.904800
# 4963                    3682               33.6367             -84.428101
#
#      Destination Point   Distance (Miles)    Makeline  Number of Airlines  \
# 4959              Point       2138.896563  LineString                  11
# 4960              Point        594.601524  LineString                  12
# 4961              Point        594.601524  LineString                  12
# 4962              Point        605.810275  LineString                  19
# 4963              Point        605.810275  LineString                  20
#
#       Origin Airport ID  Origin Latitude  Origin Longitude Origin Point
# 4959               3469        37.618999       -122.375000        Point
# 4960               3682        33.636700        -84.428101        Point
# 4961               3576        25.793200        -80.290604        Point
# 4962               3682        33.636700        -84.428101        Point
# 4963               3830        41.978600        -87.904800        Point

# %% [markdown]
# ## Checking number of Categorical and Numerical Attributes

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
#  16  hour            336776 non-null  int64
#  17  minute          336776 non-null  int64
#  18  time_hour       336776 non-null  object
# dtypes: float64(5), int64(9), object(5)
# memory usage: 48.8+ MB

# %%
plane_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5029 entries, 0 to 5028
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tailnum        5029 non-null   object
#  1   type           4480 non-null   object
#  2   manufacturer   4480 non-null   object
#  3   issue_date     4479 non-null   object
#  4   model          4480 non-null   object
#  5   status         4480 non-null   object
#  6   aircraft_type  4480 non-null   object
#  7   engine_type    4477 non-null   object
#  8   year           4335 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 353.7+ KB

# %%
flight_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4964 entries, 0 to 4963
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airport ID              4964 non-null   int64
#  1   Destination Airport     4964 non-null   object
#  2   Destination City        4964 non-null   object
#  3   Destination Country     4964 non-null   object
#  4   Destination Name        4964 non-null   object
#  5   Distance                4964 non-null   bool
#  6   Origin Airport          4964 non-null   object
#  7   Origin City             4964 non-null   object
#  8   Origin Country          4964 non-null   object
#  9   Origin Name             4964 non-null   object
#  10  Buffer                  4964 non-null   object
#  11  Destination Airport ID  4964 non-null   int64
#  12  Destination Latitude    4964 non-null   float64
#  13  Destination Longitude   4964 non-null   float64
#  14  Destination Point       4964 non-null   object
#  15  Distance (Miles)        4964 non-null   float64
#  16  Makeline                4964 non-null   object
#  17  Number of Airlines      4964 non-null   int64
#  18  Origin Airport ID       4964 non-null   int64
#  19  Origin Latitude         4964 non-null   float64
#  20  Origin Longitude        4964 non-null   float64
#  21  Origin Point            4964 non-null   object
# dtypes: bool(1), float64(5), int64(4), object(12)
# memory usage: 819.4+ KB

# %% [markdown]
# ## Checking number of missing values in each dataframe

# %%
flight.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
plane_data.isna().sum()
# Out:
# tailnum            0
# type             549
# manufacturer     549
# issue_date       550
# model            549
# status           549
# aircraft_type    549
# engine_type      552
# year             694
# dtype: int64

# %%
flight_routes.isna().sum()
# Out:
# Airport ID                0
# Destination Airport       0
# Destination City          0
# Destination Country       0
# Destination Name          0
# Distance                  0
# Origin Airport            0
# Origin City               0
# Origin Country            0
# Origin Name               0
# Buffer                    0
# Destination Airport ID    0
# Destination Latitude      0
# Destination Longitude     0
# Destination Point         0
# Distance (Miles)          0
# Makeline                  0
# Number of Airlines        0
# Origin Airport ID         0
# Origin Latitude           0
# Origin Longitude          0
# Origin Point              0
# dtype: int64

# %% [markdown]
# ## Checking number of rows in each table.

# %%
len(flight)
# Out:
# 336776

# %%
len(plane_data)
# Out:
# 5029

# %%
len(flight_routes)
# Out:
# 4964

# %% [markdown]
# ## Replacing missing values, and carrying out Data Transformation

# %% [markdown]
# Replacing the missing values `dep_time` and `arr_time` with `sched_dep_time` and `sched_arr_time` as we are assuming that if there was no actual departure and arrival time, then the plane departed and arrived as per schedule.

# %%
# Replace missing values in dep_time with sched_dep_time
flight.loc[flight['dep_time'].isna(), 'dep_time'] = flight['sched_dep_time']

# Replace missing values in arr_time with sched_arr_time
flight.loc[flight['arr_time'].isna(), 'arr_time'] = flight['sched_arr_time']

flight.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time             0
# sched_dep_time       0
# dep_delay         8255
# arr_time             0
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# Now that we have all the values in `dep_time` and `arr_time`, we can replace the missing values in `dep_delay` and `arr_delay` by subtracting the actual times with the schedule times.

# %%
import pandas as pd

# Function to convert HHMM format to total minutes
def convert_to_minutes(time_col):
    # Handle NaN cases for dep_time (since it's float64, it could have NaNs)
    time_col = time_col.fillna(0).astype(int)

    # Extract hours and minutes from HHMM format
    hours = time_col // 100
    minutes = time_col % 100

    # Convert the time into total minutes
    return hours * 60 + minutes

# Convert dep_time and sched_dep_time to minutes
flight['dep_time_minutes'] = convert_to_minutes(flight['dep_time'])
flight['sched_dep_time_minutes'] = convert_to_minutes(flight['sched_dep_time'])

# Replace missing dep_delay values by calculating dep_time - sched_dep_time
flight.loc[flight['dep_delay'].isna(), 'dep_delay'] = flight['dep_time_minutes'] - flight['sched_dep_time_minutes']

# Convert arr_time and sched_arr_time to minutes
flight['arr_time_minutes'] = convert_to_minutes(flight['arr_time'])
flight['sched_arr_time_minutes'] = convert_to_minutes(flight['sched_arr_time'])

# Replace missing arr_delay values by calculating arr_time - sched_arr_time
flight.loc[flight['arr_delay'].isna(), 'arr_delay'] = flight['arr_time_minutes'] - flight['sched_arr_time_minutes']

# Drop the intermediate time columns if no longer needed
flight = flight.drop(columns=['dep_time_minutes', 'sched_dep_time_minutes', 'arr_time_minutes', 'sched_arr_time_minutes'])

# Display the updated flight dataframe
flight.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T05:00:00Z
# 1      1416     5      29  2013-01-01T05:00:00Z
# 2      1089     5      40  2013-01-01T05:00:00Z
# 3      1576     5      45  2013-01-01T05:00:00Z
# 4       762     6       0  2013-01-01T06:00:00Z

# %%
flight.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time             0
# sched_dep_time       0
# dep_delay            0
# arr_time             0
# sched_arr_time       0
# arr_delay            0
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# Replacing the missing values in `air_time` as well by subtracting `arr_time` with `dep_time`

# %%
flight['arr_time_minutes'] = convert_to_minutes(flight['arr_time'])
flight['dep_time_minutes'] = convert_to_minutes(flight['dep_time'])

# Replace missing air_time values by calculating arr_time - dep_time
flight.loc[flight['air_time'].isna(), 'air_time'] = flight['arr_time_minutes'] - flight['dep_time_minutes']

# If you need to handle cases where the flight crosses midnight (e.g., dep_time is 2300 and arr_time is 0100):
flight.loc[flight['air_time'] < 0, 'air_time'] += 24 * 60  # Add 24 hours in minutes to fix negative values

# Drop the intermediate time columns if no longer needed
flight = flight.drop(columns=['arr_time_minutes', 'dep_time_minutes'])

# Display the updated flight dataframe
flight.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T05:00:00Z
# 1      1416     5      29  2013-01-01T05:00:00Z
# 2      1089     5      40  2013-01-01T05:00:00Z
# 3      1576     5      45  2013-01-01T05:00:00Z
# 4       762     6       0  2013-01-01T06:00:00Z

# %%
flight.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time             0
# sched_dep_time       0
# dep_delay            0
# arr_time             0
# sched_arr_time       0
# arr_delay            0
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time             0
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# Removing the `time_hour` column as it is not required

# %%
# Remove the 'time_hour' column from the flight dataframe
flight = flight.drop(columns=['time_hour'])

# Display the updated flight dataframe
flight.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute
# 0      1400     5      15
# 1      1416     5      29
# 2      1089     5      40
# 3      1576     5      45
# 4       762     6       0

# %% [markdown]
# ## Merging 2 datasets together.
#
# merging `flight` and `plane_data` using left join on `tailnum` column to create a new `merged_data`.

# %%
# Perform left join on a common key, e.g., 'plane_id'
# Replace 'plane_id' with the actual column name common to both datasets
merged_data = pd.merge(flight, plane_data, how='left', on='tailnum')

# Display the first few rows of the merged dataset
merged_data.head()
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute         type manufacturer  issue_date    model  \
# 0      1400     5      15          NaN          NaN         NaN      NaN
# 1      1416     5      29  Corporation       BOEING  07/31/1998  737-824
# 2      1089     5      40  Corporation       BOEING  12/14/1999  757-223
# 3      1576     5      45          NaN          NaN         NaN      NaN
# 4       762     6       0  Corporation       BOEING  06/26/1991  757-232
#
#   status            aircraft_type engine_type  year_y
# 0    NaN                      NaN         NaN     NaN
# 1  Valid  Fixed Wing Multi-Engine   Turbo-Fan  1998.0
# 2  Valid  Fixed Wing Multi-Engine   Turbo-Fan  1990.0
# 3    NaN                      NaN         NaN     NaN
# 4  Valid  Fixed Wing Multi-Engine   Turbo-Jet  1991.0

# %%
merged_data.isna().sum()
# Out:
# year_x                 0
# month                  0
# day                    0
# dep_time               0
# sched_dep_time         0
# dep_delay              0
# arr_time               0
# sched_arr_time         0
# arr_delay              0
# carrier                0
# flight                 0
# tailnum             2512
# origin                 0
# dest                   0
# air_time               0
# distance               0
# hour                   0
# minute                 0
# type              113992
# manufacturer      113992
# issue_date        114010
# model             113992
# status            113992
# aircraft_type     113992
# engine_type       113992
# year_y            119780
# dtype: int64

# %%
len(merged_data)
# Out:
# 336776

# %% [markdown]
# We will replace the missing values in the new columns of `merged_data` with "Not Available" because we cannot really replace these values with anything. We cannot make up these values. Hence its best suited to just replace them with saying that the data was not available.

# %% [markdown]
# "Not Available" - This will show that there are no missing values and you also don't have to loose any data points (in this case, any flights). When creating visualizations using these columns with "Not Available" values, we will just ignore the Not Available values.

# %%
# List of columns where missing values should be replaced with 'Not Available'
columns_to_fill = ['tailnum', 'type', 'manufacturer', 'issue_date', 'model', 'status', 'aircraft_type', 'engine_type', 'year_y']

# Replace missing values in these columns with 'Not Available'
merged_data[columns_to_fill] = merged_data[columns_to_fill].fillna("Not Available")

# Display the updated plane_data dataframe
merged_data.isna().sum()
# Out:
# year_x            0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# type              0
# manufacturer      0
# issue_date        0
# model             0
# status            0
# aircraft_type     0
# engine_type       0
# year_y            0
# dtype: int64

# %%
flight_routes.columns
# Out:
# Index(['Airport ID', 'Destination Airport', 'Destination City',
#        'Destination Country', 'Destination Name', 'Distance', 'Origin Airport',
#        'Origin City', 'Origin Country', 'Origin Name', 'Buffer',
#        'Destination Airport ID', 'Destination Latitude',
#        'Destination Longitude', 'Destination Point ', 'Distance (Miles)',
#        'Makeline', 'Number of Airlines', 'Origin Airport ID',
#        'Origin Latitude', 'Origin Longitude', 'Origin Point'],
#       dtype='object')

# %%
merged_data.columns
# Out:
# Index(['year_x', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'type', 'manufacturer', 'issue_date', 'model', 'status',
#        'aircraft_type', 'engine_type', 'year_y'],
#       dtype='object')

# %% [markdown]
# ## Merging the 3rd Dataset.
#
# Combining `merged_data` and `flight_routes` on `origin` and `dest`. This will give us information of Origina airport, Destination airports, Origin City, Destination City and other Route Information.

# %%
# Merge the two datasets on origin and destination airport codes
combined_data = pd.merge(merged_data, flight_routes,
                         how='left',
                         left_on=['origin', 'dest'],
                         right_on=['Origin Airport', 'Destination Airport'])

# Display the first few rows of the combined dataset
combined_data.head()
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute           type   manufacturer     issue_date  \
# 0      1400     5      15  Not Available  Not Available  Not Available
# 1      1416     5      29    Corporation         BOEING     07/31/1998
# 2      1089     5      40    Corporation         BOEING     12/14/1999
# 3      1576     5      45  Not Available  Not Available  Not Available
# 4       762     6       0    Corporation         BOEING     06/26/1991
#
#            model         status            aircraft_type    engine_type  \
# 0  Not Available  Not Available            Not Available  Not Available
# 1        737-824          Valid  Fixed Wing Multi-Engine      Turbo-Fan
# 2        757-223          Valid  Fixed Wing Multi-Engine      Turbo-Fan
# 3  Not Available  Not Available            Not Available  Not Available
# 4        757-232          Valid  Fixed Wing Multi-Engine      Turbo-Jet
#
#           year_y  Airport ID Destination Airport Destination City  \
# 0  Not Available      3494.0                 IAH          Houston
# 1         1998.0      3697.0                 IAH          Houston
# 2         1990.0      3797.0                 MIA            Miami
# 3  Not Available         NaN                 NaN              NaN
# 4         1991.0      3697.0                 ATL          Atlanta
#
#   Destination Country                                  Destination Name  \
# 0       United States      George Bush Intercontinental Houston Airport
# 1       United States      George Bush Intercontinental Houston Airport
# 2       United States                       Miami International Airport
# 3                 NaN                                               NaN
# 4       United States  Hartsfield Jackson Atlanta International Airport
#
#   Distance Origin Airport Origin City Origin Country  \
# 0    False            EWR      Newark  United States
# 1    False            LGA    New York  United States
# 2    False            JFK    New York  United States
# 3      NaN            NaN         NaN            NaN
# 4     True            LGA    New York  United States
#
#                             Origin Name   Buffer  Destination Airport ID  \
# 0  Newark Liberty International Airport  Polygon                  3550.0
# 1                    La Guardia Airport  Polygon                  3550.0
# 2  John F Kennedy International Airport  Polygon                  3576.0
# 3                                   NaN      NaN                     NaN
# 4                    La Guardia Airport  Polygon                  3682.0
#
#    Destination Latitude  Destination Longitude Destination Point   \
# 0               29.9844             -95.341400              Point
# 1               29.9844             -95.341400              Point
# 2               25.7932             -80.290604              Point
# 3                   NaN                    NaN                NaN
# 4               33.6367             -84.428101              Point
#
#    Distance (Miles)    Makeline  Number of Airlines  Origin Airport ID  \
# 0       1399.812458  LineString                 1.0             3494.0
# 1       1416.367401  LineString                 2.0             3697.0
# 2       1089.635644  LineString                 3.0             3797.0
# 3               NaN         NaN                 NaN                NaN
# 4        761.521651  LineString                 7.0             3697.0
#
#    Origin Latitude  Origin Longitude Origin Point
# 0        40.692501        -74.168701        Point
# 1        40.777199        -73.872597        Point
# 2        40.639801        -73.778900        Point
# 3              NaN               NaN          NaN
# 4        40.777199        -73.872597        Point

# %%
# Set display options to show all columns
pd.set_option('display.max_columns', None)

# Now, when you display the DataFrame, it will show all columns
combined_data.head(10)
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# 5    2013      1    1     554.0             558       -4.0     740.0
# 6    2013      1    1     555.0             600       -5.0     913.0
# 7    2013      1    1     557.0             600       -3.0     709.0
# 8    2013      1    1     557.0             600       -3.0     838.0
# 9    2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5             728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6             854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7             723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8             846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#    distance  hour  minute                 type      manufacturer  \
# 0      1400     5      15        Not Available     Not Available
# 1      1416     5      29          Corporation            BOEING
# 2      1089     5      40          Corporation            BOEING
# 3      1576     5      45        Not Available     Not Available
# 4       762     6       0          Corporation            BOEING
# 5       719     5      58        Not Available     Not Available
# 6      1065     6       0  Foreign Corporation  AIRBUS INDUSTRIE
# 7       229     6       0          Corporation          CANADAIR
# 8       944     6       0          Corporation            AIRBUS
# 9       733     6       0        Not Available     Not Available
#
#       issue_date          model         status            aircraft_type  \
# 0  Not Available  Not Available  Not Available            Not Available
# 1     07/31/1998        737-824          Valid  Fixed Wing Multi-Engine
# 2     12/14/1999        757-223          Valid  Fixed Wing Multi-Engine
# 3  Not Available  Not Available  Not Available            Not Available
# 4     06/26/1991        757-232          Valid  Fixed Wing Multi-Engine
# 5  Not Available  Not Available  Not Available            Not Available
# 6     10/05/2000       A320-232          Valid  Fixed Wing Multi-Engine
# 7     04/23/2004    CL-600-2B19          Valid  Fixed Wing Multi-Engine
# 8     09/29/2004       A320-232          Valid  Fixed Wing Multi-Engine
# 9  Not Available  Not Available  Not Available            Not Available
#
#      engine_type         year_y  Airport ID Destination Airport  \
# 0  Not Available  Not Available      3494.0                 IAH
# 1      Turbo-Fan         1998.0      3697.0                 IAH
# 2      Turbo-Fan         1990.0      3797.0                 MIA
# 3  Not Available  Not Available         NaN                 NaN
# 4      Turbo-Jet         1991.0      3697.0                 ATL
# 5  Not Available  Not Available      3494.0                 ORD
# 6      Turbo-Jet         2000.0      3494.0                 FLL
# 7      Turbo-Jet         1998.0      3697.0                 IAD
# 8      Turbo-Fan         2004.0      3797.0                 MCO
# 9  Not Available  Not Available      3697.0                 ORD
#
#   Destination City Destination Country  \
# 0          Houston       United States
# 1          Houston       United States
# 2            Miami       United States
# 3              NaN                 NaN
# 4          Atlanta       United States
# 5          Chicago       United States
# 6  Fort Lauderdale       United States
# 7       Washington       United States
# 8          Orlando       United States
# 9          Chicago       United States
#
#                                    Destination Name Distance Origin Airport  \
# 0      George Bush Intercontinental Houston Airport    False            EWR
# 1      George Bush Intercontinental Houston Airport    False            LGA
# 2                       Miami International Airport    False            JFK
# 3                                               NaN      NaN            NaN
# 4  Hartsfield Jackson Atlanta International Airport     True            LGA
# 5              Chicago O'Hare International Airport     True            EWR
# 6   Fort Lauderdale Hollywood International Airport    False            EWR
# 7           Washington Dulles International Airport     True            LGA
# 8                     Orlando International Airport     True            JFK
# 9              Chicago O'Hare International Airport     True            LGA
#
#   Origin City Origin Country                           Origin Name   Buffer  \
# 0      Newark  United States  Newark Liberty International Airport  Polygon
# 1    New York  United States                    La Guardia Airport  Polygon
# 2    New York  United States  John F Kennedy International Airport  Polygon
# 3         NaN            NaN                                   NaN      NaN
# 4    New York  United States                    La Guardia Airport  Polygon
# 5      Newark  United States  Newark Liberty International Airport  Polygon
# 6      Newark  United States  Newark Liberty International Airport  Polygon
# 7    New York  United States                    La Guardia Airport  Polygon
# 8    New York  United States  John F Kennedy International Airport  Polygon
# 9    New York  United States                    La Guardia Airport  Polygon
#
#    Destination Airport ID  Destination Latitude  Destination Longitude  \
# 0                  3550.0             29.984400             -95.341400
# 1                  3550.0             29.984400             -95.341400
# 2                  3576.0             25.793200             -80.290604
# 3                     NaN                   NaN                    NaN
# 4                  3682.0             33.636700             -84.428101
# 5                  3830.0             41.978600             -87.904800
# 6                  3533.0             26.072599             -80.152702
# 7                  3714.0             38.944500             -77.455803
# 8                  3878.0             28.429399             -81.308998
# 9                  3830.0             41.978600             -87.904800
#
#   Destination Point   Distance (Miles)    Makeline  Number of Airlines  \
# 0              Point       1399.812458  LineString                 1.0
# 1              Point       1416.367401  LineString                 2.0
# 2              Point       1089.635644  LineString                 3.0
# 3                NaN               NaN         NaN                 NaN
# 4              Point        761.521651  LineString                 7.0
# 5              Point        719.156918  LineString                 3.0
# 6              Point       1064.607704  LineString                 2.0
# 7              Point        228.624105  LineString                 1.0
# 8              Point        944.001760  LineString                 4.0
# 9              Point        733.245012  LineString                 5.0
#
#    Origin Airport ID  Origin Latitude  Origin Longitude Origin Point
# 0             3494.0        40.692501        -74.168701        Point
# 1             3697.0        40.777199        -73.872597        Point
# 2             3797.0        40.639801        -73.778900        Point
# 3                NaN              NaN               NaN          NaN
# 4             3697.0        40.777199        -73.872597        Point
# 5             3494.0        40.692501        -74.168701        Point
# 6             3494.0        40.692501        -74.168701        Point
# 7             3697.0        40.777199        -73.872597        Point
# 8             3797.0        40.639801        -73.778900        Point
# 9             3697.0        40.777199        -73.872597        Point

# %%
combined_data.columns
# Out:
# Index(['year_x', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'type', 'manufacturer', 'issue_date', 'model', 'status',
#        'aircraft_type', 'engine_type', 'year_y', 'Airport ID',
#        'Destination Airport', 'Destination City', 'Destination Country',
#        'Destination Name', 'Distance', 'Origin Airport', 'Origin City',
#        'Origin Country', 'Origin Name', 'Buffer', 'Destination Airport ID',
#        'Destination Latitude', 'Destination Longitude', 'Destination Point ',
#        'Distance (Miles)', 'Makeline', 'Number of Airlines',
#        'Origin Airport ID', 'Origin Latitude', 'Origin Longitude',
#        'Origin Point'],
#       dtype='object')

# %% [markdown]
# Removing unncessary columns that won't be required for analysis.

# %%
# Remove the 'time_hour' column from the flight dataframe
combined_data = combined_data.drop(columns=['Buffer','Makeline','Origin Latitude','Origin Longitude','Origin Point','Destination Airport ID',
                                            'Destination Latitude', 'Destination Longitude','Destination Point ','Origin Point',
                                            'Origin Point','Distance (Miles)','Origin Airport ID','Airport ID'])

# Display the updated flight dataframe
combined_data.head(55)
# Out:
#     year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0     2013      1    1     517.0             515        2.0     830.0
# 1     2013      1    1     533.0             529        4.0     850.0
# 2     2013      1    1     542.0             540        2.0     923.0
# 3     2013      1    1     544.0             545       -1.0    1004.0
# 4     2013      1    1     554.0             600       -6.0     812.0
# 5     2013      1    1     554.0             558       -4.0     740.0
# 6     2013      1    1     555.0             600       -5.0     913.0
# 7     2013      1    1     557.0             600       -3.0     709.0
# 8     2013      1    1     557.0             600       -3.0     838.0
# 9     2013      1    1     558.0             600       -2.0     753.0
# 10    2013      1    1     558.0             600       -2.0     849.0
# 11    2013      1    1     558.0             600       -2.0     853.0
# 12    2013      1    1     558.0             600       -2.0     924.0
# 13    2013      1    1     558.0             600       -2.0     923.0
# 14    2013      1    1     559.0             600       -1.0     941.0
# 15    2013      1    1     559.0             559        0.0     702.0
# 16    2013      1    1     559.0             600       -1.0     854.0
# 17    2013      1    1     600.0             600        0.0     851.0
# 18    2013      1    1     600.0             600        0.0     837.0
# 19    2013      1    1     601.0             600        1.0     844.0
# 20    2013      1    1     602.0             610       -8.0     812.0
# 21    2013      1    1     602.0             605       -3.0     821.0
# 22    2013      1    1     606.0             610       -4.0     858.0
# 23    2013      1    1     606.0             610       -4.0     837.0
# 24    2013      1    1     607.0             607        0.0     858.0
# 25    2013      1    1     608.0             600        8.0     807.0
# 26    2013      1    1     611.0             600       11.0     945.0
# 27    2013      1    1     613.0             610        3.0     925.0
# 28    2013      1    1     615.0             615        0.0    1039.0
# 29    2013      1    1     615.0             615        0.0     833.0
# 30    2013      1    1     622.0             630       -8.0    1017.0
# 31    2013      1    1     623.0             610       13.0     920.0
# 32    2013      1    1     623.0             627       -4.0     933.0
# 33    2013      1    1     624.0             630       -6.0     909.0
# 34    2013      1    1     624.0             630       -6.0     840.0
# 35    2013      1    1     627.0             630       -3.0    1018.0
# 36    2013      1    1     628.0             630       -2.0    1137.0
# 37    2013      1    1     628.0             630       -2.0    1016.0
# 38    2013      1    1     629.0             630       -1.0     824.0
# 39    2013      1    1     629.0             630       -1.0     721.0
# 40    2013      1    1     629.0             630       -1.0     824.0
# 41    2013      1    1     632.0             608       24.0     740.0
# 42    2013      1    1     635.0             635        0.0    1028.0
# 43    2013      1    1     637.0             645       -8.0     930.0
# 44    2013      1    1     639.0             640       -1.0     739.0
# 45    2013      1    1     643.0             646       -3.0     922.0
# 46    2013      1    1     643.0             645       -2.0     837.0
# 47    2013      1    1     644.0             636        8.0     931.0
# 48    2013      1    1     645.0             647       -2.0     815.0
# 49    2013      1    1     646.0             645        1.0     910.0
# 50    2013      1    1     646.0             645        1.0    1023.0
# 51    2013      1    1     651.0             655       -4.0     936.0
# 52    2013      1    1     652.0             655       -3.0     932.0
# 53    2013      1    1     653.0             700       -7.0     936.0
# 54    2013      1    1     655.0             655        0.0    1021.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0              819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1              830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2              850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3             1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4              837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5              728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6              854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7              723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8              846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9              745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
# 10             851       -2.0      B6      49  N793JB    JFK  PBI     149.0
# 11             856       -3.0      B6      71  N657JB    JFK  TPA     158.0
# 12             917        7.0      UA     194  N29129    JFK  LAX     345.0
# 13             937      -14.0      UA    1124  N53441    EWR  SFO     361.0
# 14             910       31.0      AA     707  N3DUAA    LGA  DFW     257.0
# 15             706       -4.0      B6    1806  N708JB    JFK  BOS      44.0
# 16             902       -8.0      UA    1187  N76515    EWR  LAS     337.0
# 17             858       -7.0      B6     371  N595JB    LGA  FLL     152.0
# 18             825       12.0      MQ    4650  N542MQ    LGA  ATL     134.0
# 19             850       -6.0      B6     343  N644JB    EWR  PBI     147.0
# 20             820       -8.0      DL    1919  N971DL    LGA  MSP     170.0
# 21             805       16.0      MQ    4401  N730MQ    LGA  DTW     105.0
# 22             910      -12.0      AA    1895  N633AA    EWR  MIA     152.0
# 23             845       -8.0      DL    1743  N3739P    JFK  ATL     128.0
# 24             915      -17.0      UA    1077  N53442    EWR  MIA     157.0
# 25             735       32.0      MQ    3768  N9EAMQ    EWR  ORD     139.0
# 26             931       14.0      UA     303  N532UA    JFK  SFO     366.0
# 27             921        4.0      B6     135  N635JB    JFK  RSW     175.0
# 28            1100      -21.0      B6     709  N794JB    JFK  SJU     182.0
# 29             842       -9.0      DL     575  N326NB    EWR  ATL     120.0
# 30            1014        3.0      US     245  N807AW    EWR  PHX     342.0
# 31             915        5.0      AA    1837  N3EMAA    LGA  MIA     153.0
# 32             932        1.0      UA     496  N459UA    LGA  IAH     229.0
# 33             840       29.0      EV    4626  N11107    EWR  MSP     190.0
# 34             830       10.0      MQ    4599  N518MQ    LGA  MSP     166.0
# 35            1018        0.0      US      27  N535UW    JFK  PHX     330.0
# 36            1140       -3.0      AA     413  N3BAAA    JFK  SJU     192.0
# 37             947       29.0      UA    1665  N33289    EWR  LAX     366.0
# 38             810       14.0      AA     303  N3CYAA    LGA  ORD     140.0
# 39             740      -19.0      WN    4646  N273WN    LGA  BWI      40.0
# 40             833       -9.0      US    1019  N426US    EWR  CLT      91.0
# 41             728       12.0      EV    4144  N13553    EWR  IAD      52.0
# 42             940       48.0      AA     711  N3GKAA    LGA  DFW     248.0
# 43             935       -5.0      B6     389  N709JB    LGA  MCO     144.0
# 44             749      -10.0      B6    1002  N805JB    JFK  BOS      41.0
# 45             940      -18.0      UA     556  N497UA    EWR  PBI     146.0
# 46             848      -11.0      US     926  N178US    EWR  CLT      91.0
# 47             940       -9.0      UA    1701  N75435    EWR  FLL     151.0
# 48             810        5.0      B6     102  N796JB    JFK  BUF      63.0
# 49             916       -6.0      UA     883  N569UA    LGA  DEN     243.0
# 50            1030       -7.0      UA    1496  N38727    EWR  SNA     380.0
# 51             942       -6.0      B6     203  N558JB    JFK  LAS     323.0
# 52             921       11.0      B6     117  N178JB    JFK  MSY     191.0
# 53            1009      -33.0      DL    1383  N327NW    LGA  PBI     149.0
# 54            1030       -9.0      DL    1415  N3763D    JFK  SLC     294.0
#
#     distance  hour  minute                 type  \
# 0       1400     5      15        Not Available
# 1       1416     5      29          Corporation
# 2       1089     5      40          Corporation
# 3       1576     5      45        Not Available
# 4        762     6       0          Corporation
# 5        719     5      58        Not Available
# 6       1065     6       0  Foreign Corporation
# 7        229     6       0          Corporation
# 8        944     6       0          Corporation
# 9        733     6       0        Not Available
# 10      1028     6       0        Not Available
# 11      1005     6       0          Corporation
# 12      2475     6       0          Corporation
# 13      2565     6       0        Not Available
# 14      1389     6       0        Not Available
# 15       187     5      59        Not Available
# 16      2227     6       0        Not Available
# 17      1076     6       0          Corporation
# 18       762     6       0        Not Available
# 19      1023     6       0          Corporation
# 20      1020     6      10          Corporation
# 21       502     6       5        Not Available
# 22      1085     6      10          Corporation
# 23       760     6      10        Not Available
# 24      1085     6       7        Not Available
# 25       719     6       0        Not Available
# 26      2586     6       0          Corporation
# 27      1074     6      10          Corporation
# 28      1598     6      15        Not Available
# 29       746     6      15          Corporation
# 30      2133     6      30          Corporation
# 31      1096     6      10        Not Available
# 32      1416     6      27          Corporation
# 33      1008     6      30          Corporation
# 34      1020     6      30        Not Available
# 35      2153     6      30        Not Available
# 36      1598     6      30        Not Available
# 37      2454     6      30          Corporation
# 38       733     6      30        Not Available
# 39       185     6      30          Corporation
# 40       529     6      30          Corporation
# 41       212     6       8          Corporation
# 42      1389     6      35        Not Available
# 43       950     6      45        Not Available
# 44       187     6      40        Not Available
# 45      1023     6      46          Corporation
# 46       529     6      45          Corporation
# 47      1065     6      36        Not Available
# 48       301     6      47        Not Available
# 49      1620     6      45          Corporation
# 50      2434     6      45          Corporation
# 51      2248     6      55          Corporation
# 52      1182     6      55          Corporation
# 53      1035     7       0          Corporation
# 54      1990     6      55          Corporation
#
#                      manufacturer     issue_date            model  \
# 0                   Not Available  Not Available    Not Available
# 1                          BOEING     07/31/1998          737-824
# 2                          BOEING     12/14/1999          757-223
# 3                   Not Available  Not Available    Not Available
# 4                          BOEING     06/26/1991          757-232
# 5                   Not Available  Not Available    Not Available
# 6                AIRBUS INDUSTRIE     10/05/2000         A320-232
# 7                        CANADAIR     04/23/2004      CL-600-2B19
# 8                          AIRBUS     09/29/2004         A320-232
# 9                   Not Available  Not Available    Not Available
# 10                  Not Available  Not Available    Not Available
# 11                         AIRBUS     05/04/2007         A320-232
# 12                         BOEING     03/27/1998          757-224
# 13                  Not Available  Not Available    Not Available
# 14                  Not Available  Not Available    Not Available
# 15                  Not Available  Not Available    Not Available
# 16                  Not Available  Not Available    Not Available
# 17                         AIRBUS     10/14/2004         A320-232
# 18                  Not Available  Not Available    Not Available
# 19                         AIRBUS     09/20/2006         A320-232
# 20  MCDONNELL DOUGLAS AIRCRAFT CO     06/27/1991            MD-88
# 21                  Not Available  Not Available    Not Available
# 22                         BOEING     11/16/1990          757-223
# 23                  Not Available  Not Available    Not Available
# 24                  Not Available  Not Available    Not Available
# 25                  Not Available  Not Available    Not Available
# 26                         BOEING     06/21/1991          757-222
# 27                         AIRBUS     04/04/2006         A320-232
# 28                  Not Available  Not Available    Not Available
# 29               AIRBUS INDUSTRIE     05/22/2001         A319-114
# 30               AIRBUS INDUSTRIE     10/28/2004         A319-132
# 31                  Not Available  Not Available    Not Available
# 32               AIRBUS INDUSTRIE     04/13/2000         A320-232
# 33                        EMBRAER     06/25/2003        EMB-145XR
# 34                  Not Available  Not Available    Not Available
# 35                  Not Available  Not Available    Not Available
# 36                  Not Available  Not Available    Not Available
# 37                         BOEING     07/30/2004          737-824
# 38                  Not Available  Not Available    Not Available
# 39                         BOEING     05/07/2007          737-7H4
# 40                         BOEING     12/03/2003          737-4B7
# 41                        EMBRAER     05/30/2002        EMB-145LR
# 42                  Not Available  Not Available    Not Available
# 43                  Not Available  Not Available    Not Available
# 44                  Not Available  Not Available    Not Available
# 45                         AIRBUS     09/18/2002         A320-232
# 46               AIRBUS INDUSTRIE     06/14/2001         A321-211
# 47                  Not Available  Not Available    Not Available
# 48                  Not Available  Not Available    Not Available
# 49                         BOEING     07/26/2006          757-222
# 50                         BOEING     07/14/1999          737-724
# 51                         AIRBUS     01/29/2003         A320-232
# 52                        EMBRAER     12/19/2005  ERJ 190-100 IGW
# 53               AIRBUS INDUSTRIE     04/01/1992         A320-211
# 54                         BOEING     12/20/2001          737-832
#
#            status            aircraft_type    engine_type         year_y  \
# 0   Not Available            Not Available  Not Available  Not Available
# 1           Valid  Fixed Wing Multi-Engine      Turbo-Fan         1998.0
# 2           Valid  Fixed Wing Multi-Engine      Turbo-Fan         1990.0
# 3   Not Available            Not Available  Not Available  Not Available
# 4           Valid  Fixed Wing Multi-Engine      Turbo-Jet         1991.0
# 5   Not Available            Not Available  Not Available  Not Available
# 6           Valid  Fixed Wing Multi-Engine      Turbo-Jet         2000.0
# 7           Valid  Fixed Wing Multi-Engine      Turbo-Jet         1998.0
# 8           Valid  Fixed Wing Multi-Engine      Turbo-Fan         2004.0
# 9   Not Available            Not Available  Not Available  Not Available
# 10  Not Available            Not Available  Not Available  Not Available
# 11          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2007.0
# 12          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1998.0
# 13  Not Available            Not Available  Not Available  Not Available
# 14  Not Available            Not Available  Not Available  Not Available
# 15  Not Available            Not Available  Not Available  Not Available
# 16  Not Available            Not Available  Not Available  Not Available
# 17          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2004.0
# 18  Not Available            Not Available  Not Available  Not Available
# 19          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2006.0
# 20          Valid  Fixed Wing Multi-Engine      Turbo-Fan         1991.0
# 21  Not Available            Not Available  Not Available  Not Available
# 22          Valid  Fixed Wing Multi-Engine      Turbo-Fan         1990.0
# 23  Not Available            Not Available  Not Available  Not Available
# 24  Not Available            Not Available  Not Available  Not Available
# 25  Not Available            Not Available  Not Available  Not Available
# 26          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1991.0
# 27          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2006.0
# 28  Not Available            Not Available  Not Available  Not Available
# 29          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2001.0
# 30          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1999.0
# 31  Not Available            Not Available  Not Available  Not Available
# 32          Valid  Fixed Wing Multi-Engine      Turbo-Jet         2000.0
# 33          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2002.0
# 34  Not Available            Not Available  Not Available  Not Available
# 35  Not Available            Not Available  Not Available  Not Available
# 36  Not Available            Not Available  Not Available  Not Available
# 37          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2004.0
# 38  Not Available            Not Available  Not Available  Not Available
# 39          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2007.0
# 40          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1989.0
# 41          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2002.0
# 42  Not Available            Not Available  Not Available  Not Available
# 43  Not Available            Not Available  Not Available  Not Available
# 44  Not Available            Not Available  Not Available  Not Available
# 45          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2002.0
# 46          Valid  Fixed Wing Multi-Engine      Turbo-Jet         2001.0
# 47  Not Available            Not Available  Not Available  Not Available
# 48  Not Available            Not Available  Not Available  Not Available
# 49          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1992.0
# 50          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1999.0
# 51          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2003.0
# 52          Valid  Fixed Wing Multi-Engine      Turbo-Fan         2005.0
# 53          Valid  Fixed Wing Multi-Engine      Turbo-Jet         1992.0
# 54          Valid  Fixed Wing Multi-Engine      Turbo-Jet         2001.0
#
#    Destination Airport   Destination City Destination Country  \
# 0                  IAH            Houston       United States
# 1                  IAH            Houston       United States
# 2                  MIA              Miami       United States
# 3                  NaN                NaN                 NaN
# 4                  ATL            Atlanta       United States
# 5                  ORD            Chicago       United States
# 6                  FLL    Fort Lauderdale       United States
# 7                  IAD         Washington       United States
# 8                  MCO            Orlando       United States
# 9                  ORD            Chicago       United States
# 10                 PBI    West Palm Beach       United States
# 11                 TPA              Tampa       United States
# 12                 LAX        Los Angeles       United States
# 13                 SFO      San Francisco       United States
# 14                 DFW  Dallas-Fort Worth       United States
# 15                 BOS             Boston       United States
# 16                 LAS          Las Vegas       United States
# 17                 FLL    Fort Lauderdale       United States
# 18                 ATL            Atlanta       United States
# 19                 PBI    West Palm Beach       United States
# 20                 MSP        Minneapolis       United States
# 21                 DTW            Detroit       United States
# 22                 MIA              Miami       United States
# 23                 ATL            Atlanta       United States
# 24                 MIA              Miami       United States
# 25                 ORD            Chicago       United States
# 26                 SFO      San Francisco       United States
# 27                 RSW         Fort Myers       United States
# 28                 NaN                NaN                 NaN
# 29                 ATL            Atlanta       United States
# 30                 PHX            Phoenix       United States
# 31                 MIA              Miami       United States
# 32                 IAH            Houston       United States
# 33                 MSP        Minneapolis       United States
# 34                 MSP        Minneapolis       United States
# 35                 PHX            Phoenix       United States
# 36                 NaN                NaN                 NaN
# 37                 LAX        Los Angeles       United States
# 38                 ORD            Chicago       United States
# 39                 NaN                NaN                 NaN
# 40                 CLT          Charlotte       United States
# 41                 IAD         Washington       United States
# 42                 DFW  Dallas-Fort Worth       United States
# 43                 MCO            Orlando       United States
# 44                 BOS             Boston       United States
# 45                 PBI    West Palm Beach       United States
# 46                 CLT          Charlotte       United States
# 47                 FLL    Fort Lauderdale       United States
# 48                 BUF            Buffalo       United States
# 49                 DEN             Denver       United States
# 50                 SNA          Santa Ana       United States
# 51                 LAS          Las Vegas       United States
# 52                 MSY        New Orleans       United States
# 53                 PBI    West Palm Beach       United States
# 54                 SLC     Salt Lake City       United States
#
#                                      Destination Name Distance Origin Airport  \
# 0        George Bush Intercontinental Houston Airport    False            EWR
# 1        George Bush Intercontinental Houston Airport    False            LGA
# 2                         Miami International Airport    False            JFK
# 3                                                 NaN      NaN            NaN
# 4    Hartsfield Jackson Atlanta International Airport     True            LGA
# 5                Chicago O'Hare International Airport     True            EWR
# 6     Fort Lauderdale Hollywood International Airport    False            EWR
# 7             Washington Dulles International Airport     True            LGA
# 8                       Orlando International Airport     True            JFK
# 9                Chicago O'Hare International Airport     True            LGA
# 10                   Palm Beach International Airport    False            JFK
# 11                        Tampa International Airport    False            JFK
# 12                  Los Angeles International Airport    False            JFK
# 13                San Francisco International Airport    False            EWR
# 14            Dallas Fort Worth International Airport    False            LGA
# 15  General Edward Lawrence Logan International Ai...     True            JFK
# 16                     McCarran International Airport    False            EWR
# 17    Fort Lauderdale Hollywood International Airport    False            LGA
# 18   Hartsfield Jackson Atlanta International Airport     True            LGA
# 19                   Palm Beach International Airport    False            EWR
# 20  Minneapolis-St Paul International/Wold-Chamber...    False            LGA
# 21          Detroit Metropolitan Wayne County Airport     True            LGA
# 22                        Miami International Airport    False            EWR
# 23   Hartsfield Jackson Atlanta International Airport     True            JFK
# 24                        Miami International Airport    False            EWR
# 25               Chicago O'Hare International Airport     True            EWR
# 26                San Francisco International Airport    False            JFK
# 27            Southwest Florida International Airport    False            JFK
# 28                                                NaN      NaN            NaN
# 29   Hartsfield Jackson Atlanta International Airport     True            EWR
# 30           Phoenix Sky Harbor International Airport    False            EWR
# 31                        Miami International Airport    False            LGA
# 32       George Bush Intercontinental Houston Airport    False            LGA
# 33  Minneapolis-St Paul International/Wold-Chamber...    False            EWR
# 34  Minneapolis-St Paul International/Wold-Chamber...    False            LGA
# 35           Phoenix Sky Harbor International Airport    False            JFK
# 36                                                NaN      NaN            NaN
# 37                  Los Angeles International Airport    False            EWR
# 38               Chicago O'Hare International Airport     True            LGA
# 39                                                NaN      NaN            NaN
# 40            Charlotte Douglas International Airport     True            EWR
# 41            Washington Dulles International Airport     True            EWR
# 42            Dallas Fort Worth International Airport    False            LGA
# 43                      Orlando International Airport     True            LGA
# 44  General Edward Lawrence Logan International Ai...     True            JFK
# 45                   Palm Beach International Airport    False            EWR
# 46            Charlotte Douglas International Airport     True            EWR
# 47    Fort Lauderdale Hollywood International Airport    False            EWR
# 48              Buffalo Niagara International Airport     True            JFK
# 49                       Denver International Airport    False            LGA
# 50           John Wayne Airport-Orange County Airport    False            EWR
# 51                     McCarran International Airport    False            JFK
# 52  Louis Armstrong New Orleans International Airport    False            JFK
# 53                   Palm Beach International Airport    False            LGA
# 54               Salt Lake City International Airport    False            JFK
#
#    Origin City Origin Country                           Origin Name  \
# 0       Newark  United States  Newark Liberty International Airport
# 1     New York  United States                    La Guardia Airport
# 2     New York  United States  John F Kennedy International Airport
# 3          NaN            NaN                                   NaN
# 4     New York  United States                    La Guardia Airport
# 5       Newark  United States  Newark Liberty International Airport
# 6       Newark  United States  Newark Liberty International Airport
# 7     New York  United States                    La Guardia Airport
# 8     New York  United States  John F Kennedy International Airport
# 9     New York  United States                    La Guardia Airport
# 10    New York  United States  John F Kennedy International Airport
# 11    New York  United States  John F Kennedy International Airport
# 12    New York  United States  John F Kennedy International Airport
# 13      Newark  United States  Newark Liberty International Airport
# 14    New York  United States                    La Guardia Airport
# 15    New York  United States  John F Kennedy International Airport
# 16      Newark  United States  Newark Liberty International Airport
# 17    New York  United States                    La Guardia Airport
# 18    New York  United States                    La Guardia Airport
# 19      Newark  United States  Newark Liberty International Airport
# 20    New York  United States                    La Guardia Airport
# 21    New York  United States                    La Guardia Airport
# 22      Newark  United States  Newark Liberty International Airport
# 23    New York  United States  John F Kennedy International Airport
# 24      Newark  United States  Newark Liberty International Airport
# 25      Newark  United States  Newark Liberty International Airport
# 26    New York  United States  John F Kennedy International Airport
# 27    New York  United States  John F Kennedy International Airport
# 28         NaN            NaN                                   NaN
# 29      Newark  United States  Newark Liberty International Airport
# 30      Newark  United States  Newark Liberty International Airport
# 31    New York  United States                    La Guardia Airport
# 32    New York  United States                    La Guardia Airport
# 33      Newark  United States  Newark Liberty International Airport
# 34    New York  United States                    La Guardia Airport
# 35    New York  United States  John F Kennedy International Airport
# 36         NaN            NaN                                   NaN
# 37      Newark  United States  Newark Liberty International Airport
# 38    New York  United States                    La Guardia Airport
# 39         NaN            NaN                                   NaN
# 40      Newark  United States  Newark Liberty International Airport
# 41      Newark  United States  Newark Liberty International Airport
# 42    New York  United States                    La Guardia Airport
# 43    New York  United States                    La Guardia Airport
# 44    New York  United States  John F Kennedy International Airport
# 45      Newark  United States  Newark Liberty International Airport
# 46      Newark  United States  Newark Liberty International Airport
# 47      Newark  United States  Newark Liberty International Airport
# 48    New York  United States  John F Kennedy International Airport
# 49    New York  United States                    La Guardia Airport
# 50      Newark  United States  Newark Liberty International Airport
# 51    New York  United States  John F Kennedy International Airport
# 52    New York  United States  John F Kennedy International Airport
# 53    New York  United States                    La Guardia Airport
# 54    New York  United States  John F Kennedy International Airport
#
#     Number of Airlines
# 0                  1.0
# 1                  2.0
# 2                  3.0
# 3                  NaN
# 4                  7.0
# 5                  3.0
# 6                  2.0
# 7                  1.0
# 8                  4.0
# 9                  5.0
# 10                 1.0
# 11                 4.0
# 12                 8.0
# 13                 2.0
# 14                 4.0
# 15                 4.0
# 16                 1.0
# 17                 3.0
# 18                 7.0
# 19                 2.0
# 20                 1.0
# 21                 4.0
# 22                 3.0
# 23                 7.0
# 24                 3.0
# 25                 3.0
# 26                 7.0
# 27                 1.0
# 28                 NaN
# 29                 7.0
# 30                 4.0
# 31                 3.0
# 32                 2.0
# 33                 2.0
# 34                 1.0
# 35                 4.0
# 36                 NaN
# 37                 2.0
# 38                 5.0
# 39                 NaN
# 40                 3.0
# 41                 1.0
# 42                 4.0
# 43                 2.0
# 44                 4.0
# 45                 2.0
# 46                 3.0
# 47                 2.0
# 48                 2.0
# 49                 4.0
# 50                 1.0
# 51                 8.0
# 52                11.0
# 53                 4.0
# 54                 2.0

# %%
combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport    10948
# Destination City       10948
# Destination Country    10948
# Destination Name       10948
# Distance               10948
# Origin Airport         10948
# Origin City            10948
# Origin Country         10948
# Origin Name            10948
# Number of Airlines     10948
# dtype: int64

# %% [markdown]
# Let's find out the what are the destination airports that are having missing values for the particular `dest` in our flights.

# %%
# Filter rows where 'Destination City' has missing values (NaN)
missing_destination_city = combined_data[combined_data['Destination City'].isna()]

# Get the value counts of 'dest' for those rows
dest_value_counts = missing_destination_city['dest'].value_counts()

dest_value_counts
# Out:
# dest
# SJU    5819
# BQN     896
# HNL     707
# STT     522
# BDL     443
# PSE     365
# MCI     276
# AVL     275
# IAH     274
# ACK     265
# MVY     221
# EGE     213
# MKE     183
# CRW     138
# CAE     104
# TVC     101
# BZN      36
# JAC      25
# PSP      19
# HDN      15
# MTJ      15
# BWI      15
# SBN      10
# ANC       8
# MEM       1
# BHM       1
# LGA       1
# Name: count, dtype: int64

# %% [markdown]
# Doing the same for Origin as well.

# %%
# Filter rows where 'Destination City' has missing values (NaN)
missing_origin_city = combined_data[combined_data['Origin City'].isna()]

# Get the value counts of 'dest' for those rows
missing_origin_counts = missing_destination_city['origin'].value_counts()

missing_origin_counts
# Out:
# origin
# JFK    7736
# EWR    2966
# LGA     246
# Name: count, dtype: int64

# %% [markdown]
# To manually replace the missing values in the `Destination City` and `Destination Country` column based on the `dest` codes and their corresponding cities, we can create a mapping between dest and Destination City, and then apply this mapping to fill the missing values.

# %%
# Create a mapping dictionary for 'dest' to 'Destination City'
city_mapping = {
    'SJU': 'Carolina',
    'BQN': 'Aguadilla',
    'HNL': 'Honolulu',
    'STT': 'St. Thomas',
    'BDL': 'Windsor Locks',
    'PSE': 'Ponce',
    'MCI': 'Missouri',
    'AVL': 'Fletcher',
    'IAH': 'Houston',
    'ACK': 'Nantucket',
    'MVY': 'West Tisbury',
    'EGE': 'Eagle County',
    'MKE': 'Milwaukee',
    'CRW': 'Charleston',
    'CAE': 'West Columbia',
    'TVC': 'Traverse City',
    'BZN': 'Bozeman',
    'JAC': 'Jackson',
    'PSP': 'Palm Springs',
    'HDN': 'Hayden',
    'MTJ': 'Montrose',
    'BWI': 'Baltimore',
    'SBN': 'South Bend',
    'ANC': 'Anchorage',
    'MEM': 'Memphis',
    'BHM': 'Birmingham',
    'LGA': 'LaGuardia'
}

# Create a mapping dictionary for 'dest' to 'Destination Country'
country_mapping = {
    'SJU': 'Puerto Rico',
    'BQN': 'Puerto Rico',
    'HNL': 'Hawaii',
    'STT': 'US Virgin Islands',
    'BDL': 'United States',
    'PSE': 'Puerto Rico',
    'MCI': 'United States',
    'AVL': 'United States',
    'IAH': 'United States',
    'ACK': 'United States',
    'MVY': 'United States',
    'EGE': 'United States',
    'MKE': 'United States',
    'CRW': 'United States',
    'CAE': 'United States',
    'TVC': 'United States',
    'BZN': 'United States',
    'JAC': 'United States',
    'PSP': 'United States',
    'HDN': 'United States',
    'MTJ': 'United States',
    'BWI': 'United States',
    'SBN': 'United States',
    'ANC': 'United States',
    'MEM': 'United States',
    'BHM': 'United States',
    'LGA': 'United States'
}

# Replace missing values in 'Destination City' using the city_mapping
combined_data['Destination City'] = combined_data['Destination City'].fillna(combined_data['dest'].map(city_mapping))

# Replace missing values in 'Destination Country' using the country_mapping
combined_data['Destination Country'] = combined_data['Destination Country'].fillna(combined_data['dest'].map(country_mapping))

# Display the updated combined_data dataframe
combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport    10948
# Destination City           0
# Destination Country        0
# Destination Name       10948
# Distance               10948
# Origin Airport         10948
# Origin City            10948
# Origin Country         10948
# Origin Name            10948
# Number of Airlines     10948
# dtype: int64

# %% [markdown]
# Doing the same for Origin City and Origin Country with origin

# %%
# Create a mapping dictionary for 'origin' to 'Origin City'
origin_city_mapping = {
    'JFK': 'New York',
    'EWR': 'Newark',
    'LGA': 'LaGuardia'
}

# Create a mapping dictionary for 'origin' to 'Origin Country'
origin_country_mapping = {
    'JFK': 'United States',
    'EWR': 'United States',
    'LGA': 'United States'
}

# Replace missing values in 'Origin City' using the origin_city_mapping
combined_data['Origin City'] = combined_data['Origin City'].fillna(combined_data['origin'].map(origin_city_mapping))

# Replace missing values in 'Origin Country' using the origin_country_mapping
combined_data['Origin Country'] = combined_data['Origin Country'].fillna(combined_data['origin'].map(origin_country_mapping))

combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport    10948
# Destination City           0
# Destination Country        0
# Destination Name       10948
# Distance               10948
# Origin Airport         10948
# Origin City                0
# Origin Country             0
# Origin Name            10948
# Number of Airlines     10948
# dtype: int64

# %% [markdown]
# Creating mappings for Desitnation Name and Origin Name as well.

# %%
# Create a mapping dictionary for 'dest' to 'Destination Name' (airport names)
destination_name_mapping = {
    'SJU': 'Luis Muñoz Marín International Airport',
    'BQN': 'Rafael Hernández Airport',
    'HNL': 'Daniel K. Inouye International Airport',
    'STT': 'Cyril E. King Airport',
    'BDL': 'Bradley International Airport',
    'PSE': 'Mercedita International Airport',
    'MCI': 'Kansas City International Airport',
    'AVL': 'Asheville Regional Airport',
    'IAH': 'George Bush Intercontinental Airport',
    'ACK': 'Nantucket Memorial Airport',
    'MVY': 'Martha\'s Vineyard Airport',
    'EGE': 'Eagle County Regional Airport',
    'MKE': 'General Mitchell International Airport',
    'CRW': 'Yeager Airport',
    'CAE': 'Columbia Metropolitan Airport',
    'TVC': 'Cherry Capital Airport',
    'BZN': 'Bozeman Yellowstone International Airport',
    'JAC': 'Jackson Hole Airport',
    'PSP': 'Palm Springs International Airport',
    'HDN': 'Yampa Valley Regional Airport',
    'MTJ': 'Montrose Regional Airport',
    'BWI': 'Baltimore/Washington International Thurgood Marshall Airport',
    'SBN': 'South Bend International Airport',
    'ANC': 'Ted Stevens Anchorage International Airport',
    'MEM': 'Memphis International Airport',
    'BHM': 'Birmingham-Shuttlesworth International Airport',
    'LGA': 'LaGuardia Airport'
}

# Create a mapping dictionary for 'origin' to 'Origin Name' (airport names)
origin_name_mapping = {
    'JFK': 'John F. Kennedy International Airport',
    'EWR': 'Newark Liberty International Airport',
    'LGA': 'LaGuardia Airport'
}

# Replace missing values in 'Destination Name' using the destination_name_mapping
combined_data['Destination Name'] = combined_data['Destination Name'].fillna(combined_data['dest'].map(destination_name_mapping))

# Replace missing values in 'Origin Name' using the origin_name_mapping
combined_data['Origin Name'] = combined_data['Origin Name'].fillna(combined_data['origin'].map(origin_name_mapping))

combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport    10948
# Destination City           0
# Destination Country        0
# Destination Name           0
# Distance               10948
# Origin Airport         10948
# Origin City                0
# Origin Country             0
# Origin Name                0
# Number of Airlines     10948
# dtype: int64

# %%
# Replace missing values in 'Destination Airport' with the respective values from 'dest'
combined_data['Destination Airport'] = combined_data['Destination Airport'].fillna(combined_data['dest'])

# Replace missing values in 'Origin Airport' with the respective values from 'origin'
combined_data['Origin Airport'] = combined_data['Origin Airport'].fillna(combined_data['origin'])

combined_data.head(10)
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# 5    2013      1    1     554.0             558       -4.0     740.0
# 6    2013      1    1     555.0             600       -5.0     913.0
# 7    2013      1    1     557.0             600       -3.0     709.0
# 8    2013      1    1     557.0             600       -3.0     838.0
# 9    2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5             728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6             854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7             723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8             846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#    distance  hour  minute                 type      manufacturer  \
# 0      1400     5      15        Not Available     Not Available
# 1      1416     5      29          Corporation            BOEING
# 2      1089     5      40          Corporation            BOEING
# 3      1576     5      45        Not Available     Not Available
# 4       762     6       0          Corporation            BOEING
# 5       719     5      58        Not Available     Not Available
# 6      1065     6       0  Foreign Corporation  AIRBUS INDUSTRIE
# 7       229     6       0          Corporation          CANADAIR
# 8       944     6       0          Corporation            AIRBUS
# 9       733     6       0        Not Available     Not Available
#
#       issue_date          model         status            aircraft_type  \
# 0  Not Available  Not Available  Not Available            Not Available
# 1     07/31/1998        737-824          Valid  Fixed Wing Multi-Engine
# 2     12/14/1999        757-223          Valid  Fixed Wing Multi-Engine
# 3  Not Available  Not Available  Not Available            Not Available
# 4     06/26/1991        757-232          Valid  Fixed Wing Multi-Engine
# 5  Not Available  Not Available  Not Available            Not Available
# 6     10/05/2000       A320-232          Valid  Fixed Wing Multi-Engine
# 7     04/23/2004    CL-600-2B19          Valid  Fixed Wing Multi-Engine
# 8     09/29/2004       A320-232          Valid  Fixed Wing Multi-Engine
# 9  Not Available  Not Available  Not Available            Not Available
#
#      engine_type         year_y Destination Airport Destination City  \
# 0  Not Available  Not Available                 IAH          Houston
# 1      Turbo-Fan         1998.0                 IAH          Houston
# 2      Turbo-Fan         1990.0                 MIA            Miami
# 3  Not Available  Not Available                 BQN        Aguadilla
# 4      Turbo-Jet         1991.0                 ATL          Atlanta
# 5  Not Available  Not Available                 ORD          Chicago
# 6      Turbo-Jet         2000.0                 FLL  Fort Lauderdale
# 7      Turbo-Jet         1998.0                 IAD       Washington
# 8      Turbo-Fan         2004.0                 MCO          Orlando
# 9  Not Available  Not Available                 ORD          Chicago
#
#   Destination Country                                  Destination Name  \
# 0       United States      George Bush Intercontinental Houston Airport
# 1       United States      George Bush Intercontinental Houston Airport
# 2       United States                       Miami International Airport
# 3         Puerto Rico                          Rafael Hernández Airport
# 4       United States  Hartsfield Jackson Atlanta International Airport
# 5       United States              Chicago O'Hare International Airport
# 6       United States   Fort Lauderdale Hollywood International Airport
# 7       United States           Washington Dulles International Airport
# 8       United States                     Orlando International Airport
# 9       United States              Chicago O'Hare International Airport
#
#   Distance Origin Airport Origin City Origin Country  \
# 0    False            EWR      Newark  United States
# 1    False            LGA    New York  United States
# 2    False            JFK    New York  United States
# 3      NaN            JFK    New York  United States
# 4     True            LGA    New York  United States
# 5     True            EWR      Newark  United States
# 6    False            EWR      Newark  United States
# 7     True            LGA    New York  United States
# 8     True            JFK    New York  United States
# 9     True            LGA    New York  United States
#
#                              Origin Name  Number of Airlines
# 0   Newark Liberty International Airport                 1.0
# 1                     La Guardia Airport                 2.0
# 2   John F Kennedy International Airport                 3.0
# 3  John F. Kennedy International Airport                 NaN
# 4                     La Guardia Airport                 7.0
# 5   Newark Liberty International Airport                 3.0
# 6   Newark Liberty International Airport                 2.0
# 7                     La Guardia Airport                 1.0
# 8   John F Kennedy International Airport                 4.0
# 9                     La Guardia Airport                 5.0

# %%
combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport        0
# Destination City           0
# Destination Country        0
# Destination Name           0
# Distance               10948
# Origin Airport             0
# Origin City                0
# Origin Country             0
# Origin Name                0
# Number of Airlines     10948
# dtype: int64

# %% [markdown]
# To replace the missing values in the `Number of Airlines` column with the number of airlines that fly to each Destination Airport, we can follow these steps:
#
# * Count the Number of Airlines per Destination Airport: This will involve grouping the data by `Destination Airport` and counting the number of unique airlines (`carrier`).
# * Use this information to fill missing values in Number of Airlines.

# %%
# Step 1: Group by 'Destination Airport' and count the number of unique carriers (airlines)
airlines_per_destination = combined_data.groupby('Destination Airport')['carrier'].nunique()

# Step 2: Create a mapping of 'Destination Airport' to the number of airlines
airlines_mapping = airlines_per_destination.to_dict()

airlines_mapping
# Out:
# {'ABQ': 1,
#  'ACK': 1,
#  'ALB': 1,
#  'ANC': 1,
#  'ATL': 7,
#  'AUS': 6,
#  'AVL': 2,
#  'BDL': 2,
#  'BGR': 2,
#  'BHM': 1,
#  'BNA': 5,
#  'BOS': 7,
#  'BQN': 2,
#  'BTV': 3,
#  'BUF': 4,
#  'BUR': 1,
#  'BWI': 4,
#  'BZN': 1,
#  'CAE': 2,
#  'CAK': 1,
#  'CHO': 1,
#  'CHS': 4,
#  'CLE': 5,
#  'CLT': 7,
#  'CMH': 3,
#  'CRW': 1,
#  'CVG': 4,
#  'DAY': 2,
#  'DCA': 6,
#  'DEN': 5,
#  'DFW': 4,
#  'DSM': 2,
#  'DTW': 6,
#  'EGE': 2,
#  'EYW': 1,
#  'FLL': 4,
#  'GRR': 2,
#  'GSO': 2,
#  'GSP': 2,
#  'HDN': 1,
#  'HNL': 2,
#  'HOU': 2,
#  'IAD': 6,
#  'IAH': 2,
#  'ILM': 1,
#  'IND': 5,
#  'JAC': 2,
#  'JAX': 4,
#  'LAS': 5,
#  'LAX': 5,
#  'LEX': 1,
#  'LGA': 1,
#  'LGB': 1,
#  'MCI': 3,
#  'MCO': 4,
#  'MDW': 1,
#  'MEM': 3,
#  'MHT': 2,
#  'MIA': 3,
#  'MKE': 4,
#  'MSN': 2,
#  'MSP': 6,
#  'MSY': 6,
#  'MTJ': 1,
#  'MVY': 2,
#  'MYR': 1,
#  'OAK': 1,
#  'OKC': 1,
#  'OMA': 3,
#  'ORD': 7,
#  'ORF': 3,
#  'PBI': 5,
#  'PDX': 3,
#  'PHL': 5,
#  'PHX': 5,
#  'PIT': 6,
#  'PSE': 1,
#  'PSP': 1,
#  'PVD': 1,
#  'PWM': 3,
#  'RDU': 5,
#  'RIC': 2,
#  'ROC': 3,
#  'RSW': 4,
#  'SAN': 4,
#  'SAT': 3,
#  'SAV': 1,
#  'SBN': 1,
#  'SDF': 3,
#  'SEA': 5,
#  'SFO': 5,
#  'SJC': 2,
#  'SJU': 4,
#  'SLC': 2,
#  'SMF': 1,
#  'SNA': 1,
#  'SRQ': 4,
#  'STL': 6,
#  'STT': 3,
#  'SYR': 3,
#  'TPA': 7,
#  'TUL': 1,
#  'TVC': 2,
#  'TYS': 2,
#  'XNA': 2}

# %%
combined_data['Number of Airlines'] = combined_data['Number of Airlines'].fillna(combined_data['Destination Airport'].map(airlines_mapping))

combined_data.isna().sum()
# Out:
# year_x                     0
# month                      0
# day                        0
# dep_time                   0
# sched_dep_time             0
# dep_delay                  0
# arr_time                   0
# sched_arr_time             0
# arr_delay                  0
# carrier                    0
# flight                     0
# tailnum                    0
# origin                     0
# dest                       0
# air_time                   0
# distance                   0
# hour                       0
# minute                     0
# type                       0
# manufacturer               0
# issue_date                 0
# model                      0
# status                     0
# aircraft_type              0
# engine_type                0
# year_y                     0
# Destination Airport        0
# Destination City           0
# Destination Country        0
# Destination Name           0
# Distance               10948
# Origin Airport             0
# Origin City                0
# Origin Country             0
# Origin Name                0
# Number of Airlines         0
# dtype: int64

# %%
combined_data.head(10)
# Out:
#    year_x  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# 5    2013      1    1     554.0             558       -4.0     740.0
# 6    2013      1    1     555.0             600       -5.0     913.0
# 7    2013      1    1     557.0             600       -3.0     709.0
# 8    2013      1    1     557.0             600       -3.0     838.0
# 9    2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5             728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6             854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7             723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8             846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#    distance  hour  minute                 type      manufacturer  \
# 0      1400     5      15        Not Available     Not Available
# 1      1416     5      29          Corporation            BOEING
# 2      1089     5      40          Corporation            BOEING
# 3      1576     5      45        Not Available     Not Available
# 4       762     6       0          Corporation            BOEING
# 5       719     5      58        Not Available     Not Available
# 6      1065     6       0  Foreign Corporation  AIRBUS INDUSTRIE
# 7       229     6       0          Corporation          CANADAIR
# 8       944     6       0          Corporation            AIRBUS
# 9       733     6       0        Not Available     Not Available
#
#       issue_date          model         status            aircraft_type  \
# 0  Not Available  Not Available  Not Available            Not Available
# 1     07/31/1998        737-824          Valid  Fixed Wing Multi-Engine
# 2     12/14/1999        757-223          Valid  Fixed Wing Multi-Engine
# 3  Not Available  Not Available  Not Available            Not Available
# 4     06/26/1991        757-232          Valid  Fixed Wing Multi-Engine
# 5  Not Available  Not Available  Not Available            Not Available
# 6     10/05/2000       A320-232          Valid  Fixed Wing Multi-Engine
# 7     04/23/2004    CL-600-2B19          Valid  Fixed Wing Multi-Engine
# 8     09/29/2004       A320-232          Valid  Fixed Wing Multi-Engine
# 9  Not Available  Not Available  Not Available            Not Available
#
#      engine_type         year_y Destination Airport Destination City  \
# 0  Not Available  Not Available                 IAH          Houston
# 1      Turbo-Fan         1998.0                 IAH          Houston
# 2      Turbo-Fan         1990.0                 MIA            Miami
# 3  Not Available  Not Available                 BQN        Aguadilla
# 4      Turbo-Jet         1991.0                 ATL          Atlanta
# 5  Not Available  Not Available                 ORD          Chicago
# 6      Turbo-Jet         2000.0                 FLL  Fort Lauderdale
# 7      Turbo-Jet         1998.0                 IAD       Washington
# 8      Turbo-Fan         2004.0                 MCO          Orlando
# 9  Not Available  Not Available                 ORD          Chicago
#
#   Destination Country                                  Destination Name  \
# 0       United States      George Bush Intercontinental Houston Airport
# 1       United States      George Bush Intercontinental Houston Airport
# 2       United States                       Miami International Airport
# 3         Puerto Rico                          Rafael Hernández Airport
# 4       United States  Hartsfield Jackson Atlanta International Airport
# 5       United States              Chicago O'Hare International Airport
# 6       United States   Fort Lauderdale Hollywood International Airport
# 7       United States           Washington Dulles International Airport
# 8       United States                     Orlando International Airport
# 9       United States              Chicago O'Hare International Airport
#
#   Distance Origin Airport Origin City Origin Country  \
# 0    False            EWR      Newark  United States
# 1    False            LGA    New York  United States
# 2    False            JFK    New York  United States
# 3      NaN            JFK    New York  United States
# 4     True            LGA    New York  United States
# 5     True            EWR      Newark  United States
# 6    False            EWR      Newark  United States
# 7     True            LGA    New York  United States
# 8     True            JFK    New York  United States
# 9     True            LGA    New York  United States
#
#                              Origin Name  Number of Airlines
# 0   Newark Liberty International Airport                 1.0
# 1                     La Guardia Airport                 2.0
# 2   John F Kennedy International Airport                 3.0
# 3  John F. Kennedy International Airport                 2.0
# 4                     La Guardia Airport                 7.0
# 5   Newark Liberty International Airport                 3.0
# 6   Newark Liberty International Airport                 2.0
# 7                     La Guardia Airport                 1.0
# 8   John F Kennedy International Airport                 4.0
# 9                     La Guardia Airport                 5.0

# %% [markdown]
# Finally removing some few columns. Renaming certain columns for better clarity.

# %%
# Step 1: Remove the columns 'Distance', 'Destination Airport', and 'Origin Airport'
combined_data = combined_data.drop(columns=['Distance', 'Destination Airport', 'Origin Airport'])

# Step 2: Rename 'year_x' to 'Flight Year' and 'year_y' to 'Manufacturing Year'
combined_data = combined_data.rename(columns={'year_x': 'Flight Year', 'year_y': 'Manufacturing Year'})

# %% [markdown]
# Creating a boolean `Delayed` column with `Yes` or `No` values based on if `arr_delay` > 0, then the flight was delayed. This column is going to be our target column for future machine learning models.

# %%
# Create a boolean column 'Delayed'
combined_data['Delayed'] = np.where(combined_data['arr_delay'] > 0, 'Yes', 'No')

# %% [markdown]
# ## Final Cleaned Data.
# Finally, after cleaning, transformations, reductions, quality checks, merging, we have our `combined_data` as the final cleaned data that can now be used for further EDA and answering our questions.

# %%
combined_data.head(10)
# Out:
#    Flight Year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0         2013      1    1     517.0             515        2.0     830.0
# 1         2013      1    1     533.0             529        4.0     850.0
# 2         2013      1    1     542.0             540        2.0     923.0
# 3         2013      1    1     544.0             545       -1.0    1004.0
# 4         2013      1    1     554.0             600       -6.0     812.0
# 5         2013      1    1     554.0             558       -4.0     740.0
# 6         2013      1    1     555.0             600       -5.0     913.0
# 7         2013      1    1     557.0             600       -3.0     709.0
# 8         2013      1    1     557.0             600       -3.0     838.0
# 9         2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
# 5             728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 6             854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 7             723      -14.0      EV    5708  N829AS    LGA  IAD      53.0
# 8             846       -8.0      B6      79  N593JB    JFK  MCO     140.0
# 9             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
#
#    distance  hour  minute                 type      manufacturer  \
# 0      1400     5      15        Not Available     Not Available
# 1      1416     5      29          Corporation            BOEING
# 2      1089     5      40          Corporation            BOEING
# 3      1576     5      45        Not Available     Not Available
# 4       762     6       0          Corporation            BOEING
# 5       719     5      58        Not Available     Not Available
# 6      1065     6       0  Foreign Corporation  AIRBUS INDUSTRIE
# 7       229     6       0          Corporation          CANADAIR
# 8       944     6       0          Corporation            AIRBUS
# 9       733     6       0        Not Available     Not Available
#
#       issue_date          model         status            aircraft_type  \
# 0  Not Available  Not Available  Not Available            Not Available
# 1     07/31/1998        737-824          Valid  Fixed Wing Multi-Engine
# 2     12/14/1999        757-223          Valid  Fixed Wing Multi-Engine
# 3  Not Available  Not Available  Not Available            Not Available
# 4     06/26/1991        757-232          Valid  Fixed Wing Multi-Engine
# 5  Not Available  Not Available  Not Available            Not Available
# 6     10/05/2000       A320-232          Valid  Fixed Wing Multi-Engine
# 7     04/23/2004    CL-600-2B19          Valid  Fixed Wing Multi-Engine
# 8     09/29/2004       A320-232          Valid  Fixed Wing Multi-Engine
# 9  Not Available  Not Available  Not Available            Not Available
#
#      engine_type Manufacturing Year Destination City Destination Country  \
# 0  Not Available      Not Available          Houston       United States
# 1      Turbo-Fan             1998.0          Houston       United States
# 2      Turbo-Fan             1990.0            Miami       United States
# 3  Not Available      Not Available        Aguadilla         Puerto Rico
# 4      Turbo-Jet             1991.0          Atlanta       United States
# 5  Not Available      Not Available          Chicago       United States
# 6      Turbo-Jet             2000.0  Fort Lauderdale       United States
# 7      Turbo-Jet             1998.0       Washington       United States
# 8      Turbo-Fan             2004.0          Orlando       United States
# 9  Not Available      Not Available          Chicago       United States
#
#                                    Destination Name Origin City  \
# 0      George Bush Intercontinental Houston Airport      Newark
# 1      George Bush Intercontinental Houston Airport    New York
# 2                       Miami International Airport    New York
# 3                          Rafael Hernández Airport    New York
# 4  Hartsfield Jackson Atlanta International Airport    New York
# 5              Chicago O'Hare International Airport      Newark
# 6   Fort Lauderdale Hollywood International Airport      Newark
# 7           Washington Dulles International Airport    New York
# 8                     Orlando International Airport    New York
# 9              Chicago O'Hare International Airport    New York
#
#   Origin Country                            Origin Name  Number of Airlines  \
# 0  United States   Newark Liberty International Airport                 1.0
# 1  United States                     La Guardia Airport                 2.0
# 2  United States   John F Kennedy International Airport                 3.0
# 3  United States  John F. Kennedy International Airport                 2.0
# 4  United States                     La Guardia Airport                 7.0
# 5  United States   Newark Liberty International Airport                 3.0
# 6  United States   Newark Liberty International Airport                 2.0
# 7  United States                     La Guardia Airport                 1.0
# 8  United States   John F Kennedy International Airport                 4.0
# 9  United States                     La Guardia Airport                 5.0
#
#   Delayed
# 0     Yes
# 1     Yes
# 2     Yes
# 3      No
# 4      No
# 5     Yes
# 6     Yes
# 7      No
# 8      No
# 9     Yes

# %% [markdown]
# **Incorporating suggestions from Milestone-2:**

# %%
# Compute central tendency for numeric columns
numeric_cols = combined_data.select_dtypes(include='number')

central_tendency = pd.DataFrame({
    "Mean": numeric_cols.mean(),
    "Median": numeric_cols.median(),
    "Mode": numeric_cols.mode().iloc[0]
})

print(central_tendency)
# Out:
#                            Mean  Median    Mode
# Flight Year         2013.000000  2013.0  2013.0
# month                  6.548510     7.0     7.0
# day                   15.710787    16.0    18.0
# dep_time            1352.618856  1407.0   755.0
# sched_dep_time      1344.254840  1359.0   600.0
# dep_delay             12.329263    -1.0    -5.0
# arr_time            1506.322173  1540.0  1015.0
# sched_arr_time      1536.380220  1556.0  1025.0
# arr_delay              6.677943    -4.0     0.0
# flight              1971.923620  1496.0    15.0
# air_time             150.512617   129.0    42.0
# distance            1039.912604   872.0  2475.0
# hour                  13.180247    13.0     8.0
# minute                26.230100    29.0     0.0
# Number of Airlines     3.185785     3.0     2.0

# %% [markdown]
# From the central tendency statistics we see that the data ranges over flights from 2013, with the highest number of flights occurring midyear (in the month of July, by the median and mode), the average departure time is about 2:20 PM (median = 1407), while scheduled departures are moderate before this (median = 1359), reflecting small scheduling delays. Departure delays are generally small; the median is -1 minute, suggesting that most flights leave on or before schedule, but there is a positive mean indicating some flights have large delays. Arrival times are concentrated at 3:40 PM, median 1540, and scheduled arrival times are slightly later, 1556; median arrival delay is -4 minutes, flights usually arrive on time or early. The median air time is 129 minutes, corresponding to a median distance of 872 miles; again showing most flights are short- to mid-haul. Flight numbers vary very much, with a mode of 15; that probably represents a particular popular route or carrier. Most flights fly during the 1 PM hour, median 13, and most carriers per route involve three airlines, median 3. These statistics show the airline's efficacy and nature of operations.

# %%
# Compute dispersion metrics
dispersion = pd.DataFrame({
    "Variance": numeric_cols.var(),
    "Standard Deviation": numeric_cols.std(),
    "Range": numeric_cols.max() - numeric_cols.min(),
    "IQR": numeric_cols.quantile(0.75) - numeric_cols.quantile(0.25)
})

print(dispersion)
# Out:
#                         Variance  Standard Deviation   Range     IQR
# Flight Year         0.000000e+00            0.000000     0.0     0.0
# month               1.165852e+01            3.414457    11.0     6.0
# day                 7.688847e+01            8.768607    30.0    15.0
# dep_time            2.379149e+05          487.765235  2399.0   837.0
# sched_dep_time      2.184027e+05          467.335756  2253.0   823.0
# dep_delay           1.581037e+03           39.762251  1344.0    15.0
# arr_time            2.832076e+05          532.172522  2399.0   835.0
# sched_arr_time      2.474636e+05          497.457142  2358.0   821.0
# arr_delay           2.391870e+03           48.906752  2620.0    29.0
# flight              2.664965e+06         1632.471938  8499.0  2912.0
# air_time            9.057402e+03           95.170385  1439.0   107.0
# distance            5.376307e+05          733.233033  4966.0   887.0
# hour                2.172786e+01            4.661316    22.0     8.0
# minute              3.725226e+02           19.300846    59.0    36.0
# Number of Airlines  4.014163e+00            2.003538    10.0     2.0

# %% [markdown]
# The dispersion metrics highlight variability across different attributes in the airline dataset. There is no variation in the flight year (variance = 0), as all data comes from 2013. Monthly variability is moderate (standard deviation = 3.41), with a range of 11 months and an interquartile range (IQR) of 6 months. Day values have greater dispersion due to a standard deviation of 8.77, ranging across 30 days with an IQR of 15 days. The variability in departure and arrival times, actual and scheduled, is high, with standard deviations ranging around 467 to 532 minutes, and the range falling approximately at 2300 to 2400 minutes, reflective of various flight schedules. Delays show significant variability; although the IQRs for both departure and arrival delays are 15 and 29 minutes respectively, the ranges of 1344 and 2620 minutes suggest some serious delays. Similarly, flight numbers are highly variable-standard deviation = 1632, range = 8499, IQR = 2912-presumably reflecting quite a large range of routes. Air time and distance also reveal very high dispersion: with ranges of 1439 minutes and 4966 miles and standard deviations of 95.17 minutes and 733.23 miles, respectively, these data reflect both short- and long-haul flights. Hourly schedules are less variable-standard deviation = 4.66 with a range of 22 hours-whereas minutes within an hour are more consistent-standard deviation = 19.30. With respect to the airlines per route, the standard deviation is 2.00, and the IQR is 2; this means most of the routes involve few carriers. In summary, it is a varied dataset with wide differences regarding flight operations and patterns of delay.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# Example: QQ plot for the 'distance' column
stats.probplot(combined_data['distance'].dropna(), dist="norm", plot=plt)
plt.title("QQ Plot for Distance")
plt.show()

# %%
combined_data['distance'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# The QQ plot for the "Distance" variable compares the ordered values of the dataset to a theoretical normal distribution. The red line represents the ideal scenario where the data perfectly follows a normal distribution. Points deviating significantly from the line indicate departures from normality. In this case, around the lower quantiles most of the distances are clustered around value = 0, indicating that most flight are shorter in distance. Only very few peaks can be found towards the right end tail of the distribution, indicating that very few flights are long distance. Overall, this suggests that the "Distance" variable does not follow a normal distribution and is affected by non-normal patterns, such as skewness and outliers.

# %%
from sklearn.metrics.pairwise import cosine_similarity

subset = numeric_cols.head(100)

similarity_matrix = cosine_similarity(subset)
similarity_df = pd.DataFrame(similarity_matrix, index=subset.index, columns=subset.index)

print("Cosine Similarity Matrix (first 5 rows/columns):")
print(similarity_df.iloc[:5, :5])
# Out:
# Cosine Similarity Matrix (first 5 rows/columns):
#           0         1         2         3         4
# 0  1.000000  0.999099  0.989061  0.961588  0.925653
# 1  0.999099  1.000000  0.984087  0.950361  0.911869
# 2  0.989061  0.984087  1.000000  0.977137  0.968814
# 3  0.961588  0.950361  0.977137  1.000000  0.965454
# 4  0.925653  0.911869  0.968814  0.965454  1.000000

# %% [markdown]
# The cosine similarity matrix returns insight into the similarities between data points-say, flights-based on their feature vectors. Each entry in this matrix represents the cosine similarity between any two datapoints and lies between 1 for perfect similarity and values closer to 0 for less similarity. The entries on the diagonals will all be 1 since the data point is perfectly similar to itself. Large off-diagonal values, showing high similarities between different points, vary in this subset between 0.91 and 0.99, indicating that the dataset contains strongly correlated feature vectors. For example, point 0, having a similarity of 0.99 to point 1 and 0.96 with point 3, may have shared some characteristics or patterns. Other cases of lower similarities, such as the 0.91 between points 1 and 4, show slightly more diverse data points. In general, a high cosine similarity indicates that the data points are highly related; this could imply some sort of regularity in flight patterns or behaviors in the dataset.
